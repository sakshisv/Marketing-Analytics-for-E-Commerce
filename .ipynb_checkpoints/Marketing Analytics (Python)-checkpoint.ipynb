# %% [markdown]
# # Marketing Analytics For E-Commerce Market Place Company

# %% [markdown]
# ## Business Context:
#
# The client is one of the leading online market place in India and would like partner with Analytixlabs.
# Client wants help in measuring, managing and analysing performance of business.
# Analytixlabs has hired you as an analyst for this project where client asked you to provide data
# driven insights about business and understand customer, seller behaviors, product behavior and
# channel behavior etc...
#
# ## Business Objective:
# The below are few Sample business questions to be addressed as part of this analysis.

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations
from collections import Counter

# %% [markdown]
# ### Import the data sets

# %%
customers = pd.read_csv('CUSTOMERS.csv')
sellers = pd.read_csv('SELLERS.csv')
products = pd.read_csv('PRODUCTS.csv')
orders = pd.read_csv('ORDERS.csv')
order_items = pd.read_csv('ORDER_ITEMS.csv')
order_payments = pd.read_csv('ORDER_PAYMENTS.csv')
order_review_ratings = pd.read_csv('ORDER_REVIEW_RATINGS.csv')
geo_location = pd.read_csv('GEO_LOCATION.csv')

# %% [markdown]
# ### Exploratory Data Analysis

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh

# %%
customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.dtypes
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix   seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023         Alwal
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13023         Alwal
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031     Badepalle
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195  Akkarampalle
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914       Koratla
#
#      seller_state
# 0  Andhra Pradesh
# 1  Andhra Pradesh
# 2  Andhra Pradesh
# 3  Andhra Pradesh
# 4  Andhra Pradesh

# %%
sellers.isna().sum()
# Out:
# seller_id                  0
# seller_zip_code_prefix     0
# seller_city               57
# seller_state              57
# dtype: int64

# %%
sellers.dtypes
# Out:
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object

# %%
products.head()
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             Perfumery
# 1  3aa071139cb16b67ca9e5dea641aaa2f                   Art
# 2  96bd76ec8810374ed1b65e291975717f        Sports_Leisure
# 3  cef67bcfe19066a932b7673e239eb23d                  Baby
# 4  9dc1a7de274444849c219cff195d0b71            Housewares
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name         623
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered          10/2/2017 10:56   10/2/2017 11:07
# 1    delivered          7/24/2018 20:41    7/26/2018 3:24
# 2    delivered            8/8/2018 8:38     8/8/2018 8:55
# 3    delivered         11/18/2017 19:28  11/18/2017 19:45
# 4    delivered          2/13/2018 21:18   2/13/2018 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0              10/4/2017 19:55              10/10/2017 21:25
# 1              7/26/2018 14:31                8/7/2018 15:27
# 2               8/8/2018 13:50               8/17/2018 18:06
# 3             11/22/2017 13:39                12/2/2017 0:28
# 4              2/14/2018 19:46               2/16/2018 18:17
#
#   order_estimated_delivery_date
# 0               10/18/2017 0:00
# 1                8/13/2018 0:00
# 2                 9/4/2018 0:00
# 3               12/15/2017 0:00
# 4                2/26/2018 0:00

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
# Converting orders's order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date to datetime

orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'], format = '%m/%d/%Y %H:%M')
orders['order_approved_at'] = pd.to_datetime(orders['order_approved_at'], format = '%m/%d/%Y %H:%M')
orders['order_delivered_carrier_date'] = pd.to_datetime(orders['order_delivered_carrier_date'], format = '%m/%d/%Y %H:%M')
orders['order_delivered_customer_date'] = pd.to_datetime(orders['order_delivered_customer_date'], format = '%m/%d/%Y %H:%M')
orders['order_estimated_delivery_date'] = pd.to_datetime(orders['order_estimated_delivery_date'], format = '%m/%d/%Y %H:%M')
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 2    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
# 3    delivered      2017-11-18 19:28:00 2017-11-18 19:45:00
# 4    delivered      2018-02-13 21:18:00 2018-02-13 22:20:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# 1          2018-07-26 14:31:00           2018-08-07 15:27:00
# 2          2018-08-08 13:50:00           2018-08-17 18:06:00
# 3          2017-11-22 13:39:00           2017-12-02 00:28:00
# 4          2018-02-14 19:46:00           2018-02-16 18:17:00
#
#   order_estimated_delivery_date
# 0                    2017-10-18
# 1                    2018-08-13
# 2                    2018-09-04
# 3                    2017-12-15
# 4                    2018-02-26

# %%
orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0      9/19/2017 9:45   58.90          13.29
# 1      5/3/2017 11:05  239.90          19.93
# 2     1/18/2018 14:48  199.00          17.87
# 3     8/15/2018 10:10   12.99          12.79
# 4     2/13/2017 13:57  199.90          18.14

# %%
order_items.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
## coverting order_items's shipping_limit_date to datetime
order_items["shipping_limit_date"] = pd.to_datetime(order_items["shipping_limit_date"], format="%m/%d/%Y %H:%M")
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:00   58.90          13.29
# 1 2017-05-03 11:05:00  239.90          19.93
# 2 2018-01-18 14:48:00  199.00          17.87
# 3 2018-08-15 10:10:00   12.99          12.79
# 4 2017-02-13 13:57:00  199.90          18.14

# %%
order_items.dtypes
# Out:
# order_id                       object
# order_item_id                   int64
# product_id                     object
# seller_id                      object
# shipping_limit_date    datetime64[ns]
# price                         float64
# freight_value                 float64
# dtype: object

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
order_payments.dtypes
# Out:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
order_review_ratings.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date review_answer_timestamp
# 0             4       1/18/2018 0:00         1/18/2018 21:46
# 1             5       3/10/2018 0:00          3/11/2018 3:05
# 2             5       2/17/2018 0:00         2/18/2018 14:36
# 3             5       4/21/2017 0:00         4/21/2017 22:02
# 4             5        3/1/2018 0:00          3/2/2018 10:26

# %%
order_review_ratings.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
order_review_ratings.dtypes
# Out:
# review_id                  object
# order_id                   object
# review_score                int64
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object

# %%
## converting order_review_ratings's review_creation_date & review_answer_timestamp to datetime
order_review_ratings["review_creation_date"] = pd.to_datetime(order_review_ratings["review_creation_date"], format="%m/%d/%Y %H:%M")
order_review_ratings["review_answer_timestamp"] = pd.to_datetime(order_review_ratings["review_answer_timestamp"], format="%m/%d/%Y %H:%M")
order_review_ratings.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date review_answer_timestamp
# 0             4           2018-01-18     2018-01-18 21:46:00
# 1             5           2018-03-10     2018-03-11 03:05:00
# 2             5           2018-02-17     2018-02-18 14:36:00
# 3             5           2017-04-21     2017-04-21 22:02:00
# 4             5           2018-03-01     2018-03-02 10:26:00

# %%
order_review_ratings.dtypes
# Out:
# review_id                          object
# order_id                           object
# review_score                        int64
# review_creation_date       datetime64[ns]
# review_answer_timestamp    datetime64[ns]
# dtype: object

# %%
geo_location.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1041       -23.544392       -46.639499
# 3                         1035       -23.541578       -46.641607
# 4                         1012       -23.547762       -46.635361
#
#   geolocation_city geolocation_state
# 0     Akkarampalle    Andhra Pradesh
# 1     Akkarampalle    Andhra Pradesh
# 2     Akkarampalle    Andhra Pradesh
# 3     Akkarampalle    Andhra Pradesh
# 4     Akkarampalle    Andhra Pradesh

# %%
geo_location.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
geo_location.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# dtype: object

# %% [markdown]
# ## Q1.
# ### (a) Define & calculate high level metrics like (Total Revenue, Total quantity, Total products, Total categories, Total sellers, Total locations, Total channels, Total payment methods etc…)

# %%
total_revenue = order_payments.drop_duplicates(keep = 'first')['payment_value'].sum()
print('Total Revenue:', total_revenue)

total_quantity = order_items['order_item_id'].count()
print('Total Quantity:', total_quantity)

total_products = products['product_id'].count()
print('Total Products:', total_products)

total_categories = len(products['product_category_name'].unique())
print('Total Categories:', total_categories)

total_sellers = sellers['seller_id'].count()
print('Total Sellers:', total_sellers)

total_locations = geo_location['geolocation_zip_code_prefix'].count()
print('Total Locations:', total_locations)

total_payment_methods = len(order_payments['payment_type'].unique())
print('Total Channels & Payment Methods:', total_payment_methods)
# Out:
# Total Revenue: 16008872.12
# Total Quantity: 112650
# Total Products: 32951
# Total Categories: 72
# Total Sellers: 3095
# Total Locations: 19015
# Total Channels & Payment Methods: 5

# %% [markdown]
# ### (b) Understanding how many new customers acquired every month

# %%
orders_ = pd.merge(left = customers, right = orders, on = 'customer_id', how = 'left')
orders_['year_month'] = orders_['order_purchase_timestamp'].dt.strftime('%Y-%m')
orders_.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:00
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:00
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:00
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:00
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:00
#
#     order_approved_at order_delivered_carrier_date  \
# 0 2017-05-16 15:22:00          2017-05-23 10:47:00
# 1 2018-01-12 20:58:00          2018-01-15 17:14:00
# 2 2018-05-20 16:19:00          2018-06-11 14:31:00
# 3 2018-03-13 17:29:00          2018-03-27 23:22:00
# 4 2018-07-29 10:10:00          2018-07-30 15:16:00
#
#   order_delivered_customer_date order_estimated_delivery_date year_month
# 0           2017-05-25 10:35:00                    2017-06-05    2017-05
# 1           2018-01-29 12:41:00                    2018-02-06    2018-01
# 2           2018-06-14 17:58:00                    2018-06-13    2018-05
# 3           2018-03-28 16:04:00                    2018-04-10    2018-03
# 4           2018-08-09 20:55:00                    2018-08-15    2018-07

# %%
new_cust = orders_.drop_duplicates(subset = 'customer_unique_id', keep = 'first').groupby('year_month')['customer_unique_id'].count().reset_index()
new_cust
# Out:
#    year_month  customer_unique_id
# 0     2016-09                   4
# 1     2016-10                 315
# 2     2017-01                 749
# 3     2017-02                1727
# 4     2017-03                2595
# 5     2017-04                2318
# 6     2017-05                3533
# 7     2017-06                3103
# 8     2017-07                3864
# 9     2017-08                4144
# 10    2017-09                4089
# 11    2017-10                4449
# 12    2017-11                7305
# 13    2017-12                5491
# 14    2018-01                7029
# 15    2018-02                6464
# 16    2018-03                7001
# 17    2018-04                6751
# 18    2018-05                6678
# 19    2018-06                6013
# 20    2018-07                6117
# 21    2018-08                6348
# 22    2018-09                   8
# 23    2018-10                   1

# %% [markdown]
# ### (c) Understand the retention of customers on month on month basis

# %%
orders_ = pd.merge(left = customers, right = orders, on = 'customer_id', how = 'left')
orders_['year_month'] = orders_['order_purchase_timestamp'].dt.strftime('%Y-%m')
orders_.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:00
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:00
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:00
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:00
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:00
#
#     order_approved_at order_delivered_carrier_date  \
# 0 2017-05-16 15:22:00          2017-05-23 10:47:00
# 1 2018-01-12 20:58:00          2018-01-15 17:14:00
# 2 2018-05-20 16:19:00          2018-06-11 14:31:00
# 3 2018-03-13 17:29:00          2018-03-27 23:22:00
# 4 2018-07-29 10:10:00          2018-07-30 15:16:00
#
#   order_delivered_customer_date order_estimated_delivery_date year_month
# 0           2017-05-25 10:35:00                    2017-06-05    2017-05
# 1           2018-01-29 12:41:00                    2018-02-06    2018-01
# 2           2018-06-14 17:58:00                    2018-06-13    2018-05
# 3           2018-03-28 16:04:00                    2018-04-10    2018-03
# 4           2018-08-09 20:55:00                    2018-08-15    2018-07

# %%
total_cust = orders_.groupby('year_month')['customer_unique_id'].count().reset_index()
new_cust = orders_.drop_duplicates(subset = 'customer_unique_id', keep = 'first').groupby('year_month')['customer_unique_id'].count().reset_index()

# %%
retained_cust = pd.merge(left = total_cust, right = new_cust, on = 'year_month', how = 'left', suffixes = ('_total', '_new'))
retained_cust['retained'] = retained_cust['customer_unique_id_total'] - retained_cust['customer_unique_id_new']
retained_cust
# Out:
#    year_month  customer_unique_id_total  customer_unique_id_new  retained
# 0     2016-09                         4                     4.0       0.0
# 1     2016-10                       324                   315.0       9.0
# 2     2016-12                         1                     NaN       NaN
# 3     2017-01                       800                   749.0      51.0
# 4     2017-02                      1780                  1727.0      53.0
# 5     2017-03                      2682                  2595.0      87.0
# 6     2017-04                      2404                  2318.0      86.0
# 7     2017-05                      3700                  3533.0     167.0
# 8     2017-06                      3245                  3103.0     142.0
# 9     2017-07                      4026                  3864.0     162.0
# 10    2017-08                      4331                  4144.0     187.0
# 11    2017-09                      4285                  4089.0     196.0
# 12    2017-10                      4631                  4449.0     182.0
# 13    2017-11                      7544                  7305.0     239.0
# 14    2017-12                      5673                  5491.0     182.0
# 15    2018-01                      7269                  7029.0     240.0
# 16    2018-02                      6728                  6464.0     264.0
# 17    2018-03                      7211                  7001.0     210.0
# 18    2018-04                      6939                  6751.0     188.0
# 19    2018-05                      6873                  6678.0     195.0
# 20    2018-06                      6167                  6013.0     154.0
# 21    2018-07                      6292                  6117.0     175.0
# 22    2018-08                      6512                  6348.0     164.0
# 23    2018-09                        16                     8.0       8.0
# 24    2018-10                         4                     1.0       3.0

# %% [markdown]
# ### (d) How the revenues from existing/new customers on month on month basis

# %%
orders_ = pd.merge(left = customers, right = orders, on = 'customer_id', how = 'left')
orders_['year_month'] = orders_['order_purchase_timestamp'].dt.strftime('%Y-%m')

orders_revenue = pd.merge(left = orders_, right = order_payments, on = 'order_id', how = 'left')
orders_revenue.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:00
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:00
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:00
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:00
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:00
#
#     order_approved_at order_delivered_carrier_date  \
# 0 2017-05-16 15:22:00          2017-05-23 10:47:00
# 1 2018-01-12 20:58:00          2018-01-15 17:14:00
# 2 2018-05-20 16:19:00          2018-06-11 14:31:00
# 3 2018-03-13 17:29:00          2018-03-27 23:22:00
# 4 2018-07-29 10:10:00          2018-07-30 15:16:00
#
#   order_delivered_customer_date order_estimated_delivery_date year_month  \
# 0           2017-05-25 10:35:00                    2017-06-05    2017-05
# 1           2018-01-29 12:41:00                    2018-02-06    2018-01
# 2           2018-06-14 17:58:00                    2018-06-13    2018-05
# 3           2018-03-28 16:04:00                    2018-04-10    2018-03
# 4           2018-08-09 20:55:00                    2018-08-15    2018-07
#
#    payment_sequential payment_type  payment_installments  payment_value
# 0                 1.0  credit_card                   2.0         146.87
# 1                 1.0  credit_card                   8.0         335.48
# 2                 1.0  credit_card                   7.0         157.73
# 3                 1.0  credit_card                   1.0         173.30
# 4                 1.0  credit_card                   8.0         252.25

# %%
total = orders_revenue.groupby('year_month')['payment_value'].sum().reset_index()
new = orders_revenue.drop_duplicates(subset = 'customer_unique_id', keep = 'first').groupby('year_month')['payment_value'].sum().reset_index()

# %%
existing = pd.merge(left = total, right = new, on = 'year_month', how = 'left', suffixes = ('_total', '_new'))
existing['payment_value_existing'] = existing['payment_value_total'] - existing['payment_value_new']
existing
# Out:
#    year_month  payment_value_total  payment_value_new  payment_value_existing
# 0     2016-09               252.24             252.24                    0.00
# 1     2016-10             59090.48           56990.07                 2100.41
# 2     2016-12                19.62                NaN                     NaN
# 3     2017-01            138488.04          129262.82                 9225.22
# 4     2017-02            291908.01          279455.35                12452.66
# 5     2017-03            449863.60          430270.86                19592.74
# 6     2017-04            417788.03          390268.41                27519.62
# 7     2017-05            592918.82          554778.25                38140.57
# 8     2017-06            511276.38          482425.82                28850.56
# 9     2017-07            592382.92          557405.55                34977.37
# 10    2017-08            674396.32          634243.36                40152.96
# 11    2017-09            727762.45          684413.96                43348.49
# 12    2017-10            779677.88          739331.67                40346.21
# 13    2017-11           1194882.80         1142321.70                52561.10
# 14    2017-12            878401.48          837261.66                41139.82
# 15    2018-01           1115004.18         1060793.59                54210.59
# 16    2018-02            992463.34          946496.47                45966.87
# 17    2018-03           1159652.12         1111920.62                47731.50
# 18    2018-04           1160785.48         1114751.11                46034.37
# 19    2018-05           1153982.15         1110204.26                43777.89
# 20    2018-06           1023880.50          979338.68                44541.82
# 21    2018-07           1066540.75         1022663.75                43877.00
# 22    2018-08           1022425.32          977458.14                44967.18
# 23    2018-09              4439.54            3451.93                  987.61
# 24    2018-10               589.67              89.71                  499.96

# %% [markdown]
# ### (e) Understand the trends/seasonality of sales, quantity by category, location, month, week, day, time, channel, payment method etc…

# %%
# Sales trend by category

sales_cat = pd.merge(pd.merge(orders, order_items, on = 'order_id'), products, on = 'product_id')
sales_cat.groupby('product_category_name')['order_id'].count().plot.barh(figsize = (10, 18), title = 'Trend of Sales by Category')
# Out:
# <AxesSubplot:title={'center':'Trend of Sales by Category'}, ylabel='product_category_name'>

# %%
# Sales trend by location

sales_loc = pd.merge(left = customers, right = orders, on = 'customer_id', how = 'left')
sales_loc.groupby('customer_state')['order_id'].count().plot.bar(figsize = (10, 6), title = 'Location Wise Sales Trend')
# Out:
# <AxesSubplot:title={'center':'Location Wise Sales Trend'}, xlabel='customer_state'>

# %%
# Sales trend by month

sales_monthly = orders.copy()
sales_monthly['year_month'] = sales_monthly['order_purchase_timestamp'].dt.strftime('%Y-%m')
sales_monthly = sales_monthly.groupby('year_month')['order_id'].count().reset_index()

plt.figure(figsize = (30,12))
plt.plot(sales_monthly['year_month'], sales_monthly['order_id'])
plt.title('Monthly Sales Trend', fontweight='bold', fontsize=25)
plt.xlabel('Month of Year', fontsize = 22)
plt.ylabel('Sales', fontsize = 22)
plt.show()

# %%
# Sales trend by week

sales_weekly = orders.copy()
sales_weekly['purchase_week'] = sales_weekly['order_purchase_timestamp'].dt.strftime('%Y-%W')
sales_weekly = sales_weekly.groupby('purchase_week')['order_id'].count().reset_index()

plt.figure(figsize = (32,12))
plt.plot(sales_weekly['purchase_week'], sales_weekly['order_id'])
plt.title('Weekly Sales Trend', fontweight='bold', fontsize=25)
plt.xlabel('Week of Year', fontsize = 22)
plt.ylabel('Sales', fontsize = 22)
plt.xticks(rotation=90)
plt.show()

# %%
# Sales trend by day

sales_day = orders.copy()
sales_day['year_day'] = sales_day['order_purchase_timestamp'].dt.strftime('%Y-%d')
sales_day = sales_day.groupby('year_day')['order_id'].count().reset_index()

plt.figure(figsize = (32,12))
plt.plot(sales_day['year_day'], sales_day['order_id'])
plt.title('Sales Trend Day Wise', fontweight='bold', fontsize=25)
plt.xlabel('Day of Year', fontsize = 22)
plt.ylabel('Sales', fontsize = 22)
plt.xticks(rotation=90)
plt.show()

# %%
# sales trend by time

import datetime
sales_time = orders.copy()
sales_time['time_range'] = ''
sales_time.loc[(orders_["order_purchase_timestamp"].dt.time>=datetime.time(0, 0)) &
              (orders_["order_purchase_timestamp"].dt.time<=datetime.time(6, 0)), 'time_range'] = '0-6'
sales_time.loc[(orders_["order_purchase_timestamp"].dt.time>=datetime.time(6, 0)) &
              (orders_["order_purchase_timestamp"].dt.time<=datetime.time(12, 0)), 'time_range'] = '6-12'
sales_time.loc[(orders_["order_purchase_timestamp"].dt.time>=datetime.time(12, 0)) &
              (orders_["order_purchase_timestamp"].dt.time<=datetime.time(18, 0)), 'time_range'] = '12-18'
sales_time.loc[(orders_["order_purchase_timestamp"].dt.time>=datetime.time(18, 0)), 'time_range'] = '18-24'

sales_time.groupby('time_range')['order_id'].count().plot.bar(title = 'Sales Trend by Day Time', figsize = (8,6))
# Out:
# <AxesSubplot:title={'center':'Sales Trend by Day Time'}, xlabel='time_range'>

# %%
# sales trend by payment method

sales_payment = orders.copy()
sales_payment = sales_payment.join(order_payments.set_index(['order_id']), on = ['order_id'])
sales_payment.groupby(['payment_type'])['order_id'].count().plot.pie(autopct = '%.1f%%', figsize = (8, 10), title = 'Sales Trend by Payment Method')
# Out:
# <AxesSubplot:title={'center':'Sales Trend by Payment Method'}, ylabel='order_id'>

# %%
sales_payment = orders.copy()
sales_payment = sales_payment.join(order_payments.set_index(["order_id"]), on=["order_id"])
sales_payment.groupby(["payment_type"]).agg(order_count=("order_id", "count")).plot.bar(title = 'Sales Trend by Payment Method', figsize=(8, 6))
# Out:
# <AxesSubplot:title={'center':'Sales Trend by Payment Method'}, xlabel='payment_type'>

# %% [markdown]
# ### (f) Popular Products by month, seller, state, category.

# %%
# Popular Products by Month

products_month = pd.merge(left = orders, right = order_items, on = 'order_id', how = 'left')
products_month['purchase_month'] = products_month['order_purchase_timestamp'].dt.strftime('%Y-%m')
products_month.groupby('purchase_month')['product_id'].agg(pd.Series.mode).to_frame()
# Out:
#                                       product_id
# purchase_month
# 2016-09         5a6b04657a4c5ee34285d1e4619a96b4
# 2016-10         eba7488e1c67729f045ab43fac426f2e
# 2016-12         f5d8f4fbc70ca2a0038b9a0010ed5cb0
# 2017-01         37eb69aca8718e843d897aa7b82f462d
# 2017-02         a703f5ade6e4fae527357132230ea778
# 2017-03         7e0dc102074f8285580c9777f79c90cf
# 2017-04         99a4788cb24856965c36a24e339b6058
# 2017-05         99a4788cb24856965c36a24e339b6058
# 2017-06         42a2c92a0979a949ca4ea89ec5c7b934
# 2017-07         99a4788cb24856965c36a24e339b6058
# 2017-08         f1c7f353075ce59d8a6f3cf58f419c9c
# 2017-09         422879e10f46682990de24d770e7f83d
# 2017-10         422879e10f46682990de24d770e7f83d
# 2017-11         422879e10f46682990de24d770e7f83d
# 2017-12         422879e10f46682990de24d770e7f83d
# 2018-01         aca2eb7d00ea1a7b8ebd4e68314663af
# 2018-02         e53e557d5a159f5aa2c5e995dfdf244b
# 2018-03         aca2eb7d00ea1a7b8ebd4e68314663af
# 2018-04         53b36df67ebb7c41585e8d54d6772e08
# 2018-05         53b36df67ebb7c41585e8d54d6772e08
# 2018-06         19c91ef95d509ea33eda93495c4d3481
# 2018-07         d285360f29ac7fd97640bf0baef03de0
# 2018-08         e7cc48a9daff5436f63d3aad9426f28b
# 2018-09         b98992ea80b467987a7fbb88e7f2076a
# 2018-10                                       []

# %%
# Popular Products by Seller

products_seller = pd.merge(pd.merge(orders, order_items, on = 'order_id'), sellers, on = 'seller_id')
products_seller.groupby('seller_id')['product_id'].agg(pd.Series.mode).to_frame()
# Out:
#                                                                          product_id
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532                   a2ff5a97bf95719e38ea2e3b4105bce8
# 001cca7ae9ae17fb1caed9dfb1094831                   08574b074924071f4e201e151b152b4e
# 001e6ad469a905060d959994f1b41e4f                   093cd981b714bcdff182b427d87fc8fc
# 002100f778ceb8431b7a1020ff7ab48f                   158102fe543dbaeb84d87811bfe06d0d
# 003554e2dce176b5555353e4f3555ac8                   67f36b3689147d882d2b298fd0715d80
# ...                                                                             ...
# ffcfefa19b08742c5d315f2791395ee5                   cea898bfbca0b5b0e7b36cecd350709e
# ffdd9f82b9a447f6f8d4b91554cc7dd3                   ada800a927673ac73cdfbbd2c832331b
# ffeee66ac5d5a62fe688b9d26f83f534                   1347d4320dcd0acd750e37bb3d94a918
# fffd5413c0700ac820c7069d66d98c89                   ebb12274522d82caa7dca657873b2ad7
# ffff564a4f9085cd26170f4732393726  [8f7a3322e1abfed89ac080b0f7364779, 96aca2f53bc...
#
# [3095 rows x 1 columns]

# %%
# Popular Products by State

products_state = pd.merge(pd.merge(orders, order_items, on = 'order_id'), customers, on = 'customer_id')
products_state.groupby('customer_state')['product_id'].agg(pd.Series.mode).to_frame()
# Out:
#                                                           product_id
# customer_state
# Andhra Pradesh                      aca2eb7d00ea1a7b8ebd4e68314663af
# Arunachal Pradesh                   03e1c946c0ddfc58724ff262aef08dff
# Chhattisgarh       [368c6c730842d78016ad823897a372db, 422879e10f4...
# Delhi                               53759a2ecddad2bb87a079a1f1519f73
# Goa                [2a5806f10d0f00e5ad032dd2e3c8806e, 3db53484d66...
# Gujarat            [53759a2ecddad2bb87a079a1f1519f73, aca2eb7d00e...
# Haryana                             2b4609f8948be18874494203496bc318
# Himachal Pradesh   [422879e10f46682990de24d770e7f83d, 4316b712956...
# Jammu & Kashmir                     89b190a046022486c635022524a974a8
# Karnataka                           422879e10f46682990de24d770e7f83d
# Kerala                              aca2eb7d00ea1a7b8ebd4e68314663af
# Madhya Pradesh                      99a4788cb24856965c36a24e339b6058
# Maharashtra                         99a4788cb24856965c36a24e339b6058
# Orissa             [aca2eb7d00ea1a7b8ebd4e68314663af, b5c4b2c6b8c...
# Punjab                              d1c427060a0f73f6b889a5c7c61f2ac4
# Rajasthan          [368c6c730842d78016ad823897a372db, 3dd2a17168e...
# Tamil Nadu                          99a4788cb24856965c36a24e339b6058
# Uttar Pradesh                       3dd2a17168ec895c781a9191c1e95ad7
# Uttaranchal        [53759a2ecddad2bb87a079a1f1519f73, f919da4f716...
# West Bengal                         99a4788cb24856965c36a24e339b6058

# %%
# Popular Products by Category

products_cat = pd.merge(pd.merge(orders, order_items, on = 'order_id'), products, on = 'product_id')
products_cat.groupby('product_category_name')['product_id'].agg(pd.Series.mode).to_frame()
# Out:
#                                                   product_id
# product_category_name
# Agro_Industry_And_Commerce  11250b0d4b709fee92441c5f34122aed
# Air_Conditioning            98e91d0f32954dcd8505875bb2b42cdb
# Art                         4fe644d766c7566dbc46fb851363cb3b
# Arts_And_Craftmanship       b9976e9c22fb1540bd71d1bcd2989475
# Audio                       db5efde3ad0cc579b130d71c4b2db522
# ...                                                      ...
# Stationery                  fb55982be901439613a95940feefd9ee
# Tablets_Printing_Image      6bbe55cf8f85c87b6eebb775a53402f4
# Telephony                   e7cc48a9daff5436f63d3aad9426f28b
# Toys                        880be32f4db1d9f6e2bec38fb6ac23ab
# Watches_Gifts               53b36df67ebb7c41585e8d54d6772e08
#
# [71 rows x 1 columns]

# %% [markdown]
# ### (g) Popular categories by state, month

# %%
# Popular categories by state

cat_state = pd.merge(pd.merge(pd.merge(orders, order_items, on = 'order_id'), products, on = 'product_id'), customers, on = 'customer_id')
cat_state.groupby('customer_state')['product_category_name'].agg(pd.Series.mode).to_frame()
# Out:
#                                                product_category_name
# customer_state
# Andhra Pradesh                                        Bed_Bath_Table
# Arunachal Pradesh                                     Bed_Bath_Table
# Chhattisgarh                                          Bed_Bath_Table
# Delhi                                                  Health_Beauty
# Goa                [Auto, Construction_Tools_Construction, Cool_S...
# Gujarat                                               Bed_Bath_Table
# Haryana                                               Bed_Bath_Table
# Himachal Pradesh                                      Bed_Bath_Table
# Jammu & Kashmir                                       Bed_Bath_Table
# Karnataka                                             Bed_Bath_Table
# Kerala                                                Bed_Bath_Table
# Madhya Pradesh                                        Bed_Bath_Table
# Maharashtra                                           Bed_Bath_Table
# Orissa                                                Bed_Bath_Table
# Punjab                                                 Health_Beauty
# Rajasthan                                             Sports_Leisure
# Tamil Nadu                                            Bed_Bath_Table
# Uttar Pradesh                                          Health_Beauty
# Uttaranchal                                               Cool_Stuff
# West Bengal                                            Health_Beauty

# %%
# Popular categories by month

cat_month = pd.merge(pd.merge(pd.merge(orders, order_items, on = 'order_id'), products, on = 'product_id'), customers, on = 'customer_id')
cat_month['year_month'] = cat_month['order_purchase_timestamp'].dt.strftime('%Y-%m')
cat_month.groupby('year_month')['product_category_name'].agg(pd.Series.mode).to_frame()
# Out:
#                               product_category_name
# year_month
# 2016-09                               Health_Beauty
# 2016-10                             Furniture_Decor
# 2016-12                    Fashion_Bags_Accessories
# 2017-01                             Furniture_Decor
# 2017-02                             Furniture_Decor
# 2017-03                             Furniture_Decor
# 2017-04                              Bed_Bath_Table
# 2017-05                              Bed_Bath_Table
# 2017-06                              Bed_Bath_Table
# 2017-07                              Bed_Bath_Table
# 2017-08                              Bed_Bath_Table
# 2017-09                              Bed_Bath_Table
# 2017-10                              Bed_Bath_Table
# 2017-11                              Bed_Bath_Table
# 2017-12                              Bed_Bath_Table
# 2018-01                              Bed_Bath_Table
# 2018-02                       Computers_Accessories
# 2018-03                              Bed_Bath_Table
# 2018-04                              Bed_Bath_Table
# 2018-05                               Health_Beauty
# 2018-06                               Health_Beauty
# 2018-07                               Health_Beauty
# 2018-08                               Health_Beauty
# 2018-09     Kitchen_Dining_Laundry_Garden_Furniture

# %% [markdown]
# ### (h) List top 10 most expensive products sorted by price

# %%
top10_products = pd.merge(pd.merge(orders, order_items, on = 'order_id'), products, on = 'product_id')
top10_products.groupby('product_category_name')['price'].sum().sort_values(ascending = False).reset_index().head(10)
# Out:
#    product_category_name       price
# 0          Health_Beauty  1258681.34
# 1          Watches_Gifts  1205005.68
# 2         Bed_Bath_Table  1036988.68
# 3         Sports_Leisure   988048.97
# 4  Computers_Accessories   911954.32
# 5        Furniture_Decor   729762.49
# 6             Cool_Stuff   635290.85
# 7             Housewares   632248.66
# 8                   Auto   592720.11
# 9           Garden_Tools   485256.46

# %% [markdown]
# ### 2. Performing Customers/sellers Segmentation
# ### (a) Divide the customers into groups based on the revenue generated.

# %%
## dividing customers on the basis of revenue by percentile in four categories :
    ## category1 ==> highest revenue generating customers 75%le and above
    ## category2 ==> high revenue generating customers 50%le to 75%le
    ## category3 ==> medium revenue generating customers 25%le to 50%le
    ## category4 ==> low revenue generating customers 0%le to 25%le
    
cust_revenue = pd.merge(pd.merge(orders, order_payments, on = 'order_id'), customers, on = 'customer_id')
cust_revenue = cust_revenue.groupby('customer_id')['payment_value'].sum().sort_values(ascending = False).reset_index()
cust_revenue['customers_category'] = pd.qcut(cust_revenue['payment_value'], q = [0, 0.25, 0.50, 0.75, 1], labels = ['category4', 'category3', 'category2', 'category1'])
cust_revenue
# Out:
#                             customer_id  payment_value customers_category
# 0      1617b1357756262bfa56ab541c47bc16       13664.08          category1
# 1      ec5b2ba62e574342386871631fafd3fc        7274.88          category1
# 2      c6e2731c5b391845f6800c97401a43a9        6929.31          category1
# 3      f48d464a0baaea338cb25f816991ab1f        6922.21          category1
# 4      3fd6777bbce08a352fddd04e4a7cc8f6        6726.66          category1
# ...                                 ...            ...                ...
# 99435  184e8e8e48937145eb96c721ef1f0747          10.07          category4
# 99436  a790343ca6f3fee08112d678b43aa7c5           9.59          category4
# 99437  a73c1f73f5772cf801434bf984b0b1a7           0.00          category4
# 99438  3532ba38a3fd242259a514ac2b6ae6b6           0.00          category4
# 99439  197a2a6a77da93f678ea0d379f21da0a           0.00          category4
#
# [99440 rows x 3 columns]

# %% [markdown]
# ### (b) Divide the sellers into groups based on the revenue generated.

# %%
## dividing sellers on the basis of revenue by percentile in four categories :
    ## category1 ==> highest revenue generating sellers 75%le and above
    ## category2 ==> high revenue generating sellers 50%le to 75%le
    ## category3 ==> medium revenue generating sellers 25%le to 50%le
    ## category4 ==> low revenue generating sellers 0%le to 25%le
    
sellers_revenue = pd.merge(pd.merge(orders, order_payments, on = 'order_id'), order_items, on = 'order_id')
sellers_revenue = sellers_revenue.groupby('seller_id')['payment_value'].sum().sort_values(ascending = False).reset_index()
sellers_revenue['sellers_category'] = pd.qcut(sellers_revenue['payment_value'], q = [0, 0.25, 0.50, 0.75, 1], labels = ['category4', 'category3', 'category2', 'category1'])
sellers_revenue
# Out:
#                              seller_id  payment_value sellers_category
# 0     7c67e1448b00f6e969d365cea6b010ab      507166.91        category1
# 1     1025f0e2d44d7041d6cf58b6550e0bfa      308222.04        category1
# 2     4a3ca9315b744ce9f8e9374361493884      301245.27        category1
# 3     1f50f920176fa81dab994f9023523100      290253.42        category1
# 4     53243585a1d6dc2643021fd1853d8905      284903.08        category1
# ...                                ...            ...              ...
# 3090  ad14615bdd492b01b0d97922e87cb87f          19.21        category4
# 3091  702835e4b785b67a084280efca355756          18.56        category4
# 3092  4965a7002cca77301c82d3f91b82e1a9          16.36        category4
# 3093  77128dec4bec4878c37ab7d6169d6f26          15.22        category4
# 3094  cf6f6bc4df3999b9c6440f124fb2f687          12.22        category4
#
# [3095 rows x 3 columns]

# %% [markdown]
# ### 3. Cross-Selling (Which products are selling together)
# Hint: We need to find which of the top 10 combinations of products are selling together in
# each transaction. (combination of 2 or 3 buying together)

# %%
# Combination of prduct_id:

cross_selling = pd.merge(orders, order_items, how = 'left', on = 'order_id')

# %%
# Create a combination of products so that can be used as an alternative to pairing

df1 = cross_selling
df1 = df1.dropna()
df1 = df1[df1['order_id'].duplicated(keep = False)]
df1['products'] = df1.groupby('order_id')['product_id'].transform(lambda x:','.join(x))
df1 = df1[['order_id', 'products']].drop_duplicates()
df1.head()
# Out:
#                             order_id  \
# 10  e6ce16cb79ec1d90b1da9085a6118aeb
# 27  acce194856392f074dbf9dada14d8d82
# 54  9faeb9b2746b9d7526aef5acb08e2aa0
# 60  66e4624ae69e7dc89bd50222b59f581f
# 68  688052146432ef8253587b930b01a06d
#
#                                              products
# 10  08574b074924071f4e201e151b152b4e,08574b0749240...
# 27  d70f38e7f79c630f8ea00c993897042c,9451e630d725c...
# 54  f48eb5c2fde13ca63664f0bb05f55346,f48eb5c2fde13...
# 60  b37b72d5a56f887725c2862184b8cab8,b37b72d5a56f8...
# 68  d1c427060a0f73f6b889a5c7c61f2ac4,db56f6d2b04c8...

# %%
# Count each row combination by the the pairing of the two:

count = Counter()
for row in df1['products']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

count
# Out:
# Counter({('08574b074924071f4e201e151b152b4e',
#           '08574b074924071f4e201e151b152b4e'): 17,
#          ('d70f38e7f79c630f8ea00c993897042c',
#           '9451e630d725c4bb7a5a206b48b99486'): 1,
#          ('f48eb5c2fde13ca63664f0bb05f55346',
#           'f48eb5c2fde13ca63664f0bb05f55346'): 1,
#          ('b37b72d5a56f887725c2862184b8cab8',
#           'b37b72d5a56f887725c2862184b8cab8'): 1,
#          ('d1c427060a0f73f6b889a5c7c61f2ac4',
#           'db56f6d2b04c89eae4daba188842fd7b'): 1,
#          ('d457916b4fdc60154ed93b5dd3e6fd69',
#           'd457916b4fdc60154ed93b5dd3e6fd69'): 1,
#          ('a659cb33082b851fb87a33af8f0fff29',
#           'a659cb33082b851fb87a33af8f0fff29'): 27,
#          ('a5a0e71a81ae65aa335e71c06261e260',
#           'a5a0e71a81ae65aa335e71c06261e260'): 10,
#          ('75d6b6963340c6063f7f4cfcccfe6a30',
#           '75d6b6963340c6063f7f4cfcccfe6a30'): 2,
#          ('c3ba4e8d3cb30049213b682e751e9d00',
#           'c3ba4e8d3cb30049213b682e751e9d00'): 2,
#          ('425db55cb3b0f5b18a2d9964da31c3c0',
#           '425db55cb3b0f5b18a2d9964da31c3c0'): 1,
#          ('c63857f1b80521fbf01eb987423d0ccd',
#           'c63857f1b80521fbf01eb987423d0ccd'): 1,
#          ('120fa011365fc39efe382cba4e50999e',
#           '68a058d125ba1544e726898f0b8c0523'): 1,
#          ('120fa011365fc39efe382cba4e50999e',
#           'eab67bf937aaadc19f83383a331d2dd9'): 1,
#          ('68a058d125ba1544e726898f0b8c0523',
#           'eab67bf937aaadc19f83383a331d2dd9'): 1,
#          ('a6ad77b15e566298a4e8ee2011ab1255',
#           'a6ad77b15e566298a4e8ee2011ab1255'): 46,
#          ('12bc892d6fff0dc42c8177f3665ef00e',
#           '12bc892d6fff0dc42c8177f3665ef00e'): 2,
#          ('dbb67791e405873b259e4656bf971246',
#           'dbb67791e405873b259e4656bf971246'): 38,
#          ('c7079d23bead81759eb7c670b96728bc',
#           '04a4e9d8c0dc6b2b4b8e24ea78a8f318'): 2,
#          ('04a4e9d8c0dc6b2b4b8e24ea78a8f318',
#           '04a4e9d8c0dc6b2b4b8e24ea78a8f318'): 1,
#          ('51c59cf09066762ba5740772b0a86215',
#           'f889fb87b505b73de10c18b93352469f'): 1,
#          ('216bb0e0cd43ffd832e0973d35e0377e',
#           '216bb0e0cd43ffd832e0973d35e0377e'): 32,
#          ('77ccbcf251886c8b83676fc918e7336c',
#           '1e56c680b07833e85fec6904b2c7e4b8'): 1,
#           'd6fa8b99ed80bff9dcddd3fdefa6e68d'): 1,
#          ('507914b4af243e0589c389ac50545ef6',
#           '26facbccf840188b92bcc8cb89fe1f64'): 1,
#          ('507914b4af243e0589c389ac50545ef6',
#           '678c229b41c0e497d35a25a8be1cc631'): 1,
#          ('507914b4af243e0589c389ac50545ef6',
#           '5dae498eff2d80057f56122235a36aff'): 1,
#          ('5b1f3328a2c6f837ecce21bca1489939',
#           'd6fa8b99ed80bff9dcddd3fdefa6e68d'): 1,
#          ('5b1f3328a2c6f837ecce21bca1489939',
#           '26facbccf840188b92bcc8cb89fe1f64'): 1,
#          ('5b1f3328a2c6f837ecce21bca1489939',
#           '678c229b41c0e497d35a25a8be1cc631'): 1,
#          ('5b1f3328a2c6f837ecce21bca1489939',
#           '5dae498eff2d80057f56122235a36aff'): 1,
#          ('d6fa8b99ed80bff9dcddd3fdefa6e68d',
#           '26facbccf840188b92bcc8cb89fe1f64'): 1,
#          ('d6fa8b99ed80bff9dcddd3fdefa6e68d',
#           '678c229b41c0e497d35a25a8be1cc631'): 1,
#          ('d6fa8b99ed80bff9dcddd3fdefa6e68d',
#           '5dae498eff2d80057f56122235a36aff'): 1,
#          ('26facbccf840188b92bcc8cb89fe1f64',
#           '678c229b41c0e497d35a25a8be1cc631'): 1,
#          ('26facbccf840188b92bcc8cb89fe1f64',
#           '5dae498eff2d80057f56122235a36aff'): 1,
#          ('678c229b41c0e497d35a25a8be1cc631',
#           '5dae498eff2d80057f56122235a36aff'): 1,
#          ('cbff1df298f7bfd7b65557cfc4133d62',
#           'cbff1df298f7bfd7b65557cfc4133d62'): 4,
#          ('b5aebb467d9a92162173cbd234e00d99',
#           'b5aebb467d9a92162173cbd234e00d99'): 2,
# ...
#          ('4fcb3d9a5f4871e8362dfedbdb02b064',
#           'f4f67ccaece962d013a4e1d7dc3a61f7'): 6,
#          ('4796d7d7634cb23b1870940964bc4468',
#           '4796d7d7634cb23b1870940964bc4468'): 1,
#          ('f40ef461e35cca158e568c17293fb5be',
#           'edc388b2ba34de112c918ddcd465f5e9'): 1,
#          ('efefc6ae386eed5b7286cdae6168d55b',
#           '8cdb9ebdf8dcdd09f8495eec1851b0ae'): 1,
#          ('d730dcd6017ae7bc8a4b5561f18c6d59',
#           'e389381479408ccdcdd406d8d3049e45'): 2,
#          ('e389381479408ccdcdd406d8d3049e45',
#           'e389381479408ccdcdd406d8d3049e45'): 2,
#          ('430315bedd89f81ceec11ba8cc51ebe1',
#           '430315bedd89f81ceec11ba8cc51ebe1'): 1,
#          ('09c3a2ea33f044aebffecd6681e00133',
#           'd011223de539cd224b5c5c8082313d46'): 1,
#          ('09c3a2ea33f044aebffecd6681e00133',
#           '09c3a2ea33f044aebffecd6681e00133'): 8,
#          ('d011223de539cd224b5c5c8082313d46',
#           '09c3a2ea33f044aebffecd6681e00133'): 1,
#          ('694cbe624717957c7536ef8cd9dfbf57',
#           '694cbe624717957c7536ef8cd9dfbf57'): 1,
#          ('a8075470f960215ffb67624782f80fec',
#           'a8075470f960215ffb67624782f80fec'): 1,
#           '8c591ab0ca519558779df02023177f44'): 14,
#          ('61f892cad282d3059bd33ae0eef5b02d',
#           '61f892cad282d3059bd33ae0eef5b02d'): 1,
#          ('0bb7d5c406dd6affef3cd4f5d6744844',
#           '28d7da9ebe96bfda54aed060b68b23a1'): 1,
#          ('0bb7d5c406dd6affef3cd4f5d6744844',
#           '9a442e31dcb07042eca00d73c1933880'): 1,
#          ('28d7da9ebe96bfda54aed060b68b23a1',
#           '9a442e31dcb07042eca00d73c1933880'): 1,
#          ('5edf955f0c8417e3fea7288360c2e22d',
#           '188c9cb0aff9e485e3f84752731c633a'): 1,
#          ('30048c2138eb22aebd13d31c07ba226b',
#           '30048c2138eb22aebd13d31c07ba226b'): 4,
#          ('e4ca5b20cfe1a020e15e36fe14e880ee',
#           'e4ca5b20cfe1a020e15e36fe14e880ee'): 3,
#          ('e1310a0690f541f25a1d33cf395d5407',
#           'e1310a0690f541f25a1d33cf395d5407'): 1,
#          ('887b93e713558fd03647419a99268159',
#           'cf9eef3269d316b89f8539aafc0db5b4'): 1,
#          ('99a4788cb24856965c36a24e339b6058',
#           '99a4788cb24856965c36a24e339b6058'): 23,
#          ('a72209f6ea270769cecf0ed4168d3893',
#           'a72209f6ea270769cecf0ed4168d3893'): 1,
#          ('4ebab6a2135a2477b657bda38646b64b',
#           '4ebab6a2135a2477b657bda38646b64b'): 1,
#          ('c5f80e9b4f6f51bc7cdb5d004643262a',
#           '6c134d5cb3a3dd71dd85c1b5cb4fc7b0'): 1,
#          ('a7d454bed93698b6ddb23f865e69f111',
#           'a7d454bed93698b6ddb23f865e69f111'): 3,
#          ('8b5a201cdb79e1962baa08534f71d382',
#           '89ea72335f0b688b56ba7daa5a2e98c2'): 1,
#          ('7b22327a8222cb724f17c3a0aa392517',
#           '7b22327a8222cb724f17c3a0aa392517'): 1,
#          ('276f08e98f8f7711c2785ce40fc9d4d9',
#           '276f08e98f8f7711c2785ce40fc9d4d9'): 6,
#          ('87cb507e0daa37bbf34956fd59eba832',
#           '186fe07c8b8005ec6a498587ffbc1352'): 1,
#          ('1cdfaf0cc5abd6063d3a10ae3318f345',
#           '1cdfaf0cc5abd6063d3a10ae3318f345'): 1,
#          ('4f0abfbee7569e43b80f9aaa256a9bf8',
#           '3a362c0e7f9a69276e2d95869a3e143b'): 1,
#          ('c0d8d4693da67263b21c9b485cd02898',
#           'c0d8d4693da67263b21c9b485cd02898'): 1,
#          ('0be487faac01dd57fd7ed17cfbdf2dee',
#           '4d272fe20c57c64dc74b3db191fc31ef'): 2,
#          ('25e2023ed83352bde98dc1490d14c3d8',
#           '25e2023ed83352bde98dc1490d14c3d8'): 2,
#          ('6630485063578b527549697547ed3ed5',
#           '6630485063578b527549697547ed3ed5'): 2,
#          ('368c6c730842d78016ad823897a372db',
#           '53759a2ecddad2bb87a079a1f1519f73'): 6,
#          ('368c6c730842d78016ad823897a372db',
#           '0bcc3eeca39e1064258aa1e932269894'): 4,
#          ('53759a2ecddad2bb87a079a1f1519f73',
#           '0bcc3eeca39e1064258aa1e932269894'): 5,
#           'f7e5d21b19afd9b7b543e68501ceef6b'): 3,
#          ('0d85c435fd60b277ffb9e9b0f88f927a',
#           '0d85c435fd60b277ffb9e9b0f88f927a'): 11,
#          ('83e2059df06602e05d9bc1abf28166ac',
#           '83e2059df06602e05d9bc1abf28166ac'): 1,
#          ('83e2059df06602e05d9bc1abf28166ac',
#           '4006da5107400e5ac48dbcc829a36c42'): 2,
#          ('83e2059df06602e05d9bc1abf28166ac',
#           '281905b21f01db1009fd7c01b10dd1d4'): 2,
#          ('83e2059df06602e05d9bc1abf28166ac',
#           '3c7c75671b25b927f05e68b233263e5f'): 6,
#          ('4006da5107400e5ac48dbcc829a36c42',
#           '281905b21f01db1009fd7c01b10dd1d4'): 1,
#          ('4006da5107400e5ac48dbcc829a36c42',
#           '3c7c75671b25b927f05e68b233263e5f'): 3,
#          ('281905b21f01db1009fd7c01b10dd1d4',
#           '3c7c75671b25b927f05e68b233263e5f'): 3,
#          ('3c7c75671b25b927f05e68b233263e5f',
#           '3c7c75671b25b927f05e68b233263e5f'): 3,
#          ('a1efabfd513c691eeb2650e5f04e5cb6',
#           'a1efabfd513c691eeb2650e5f04e5cb6'): 2,
#          ('65dfa5d20f4beb1a0f6aad75c004434f',
#           'ddceb6eef6af67e9fbbd4c148dbe5fd9'): 1,
#          ('0c5193db708519e6b812ac8474898ffa',
#           '0c5193db708519e6b812ac8474898ffa'): 2,
#          ('c55c10c2e37e534c37d1e6694612664c',
#           'c55c10c2e37e534c37d1e6694612664c'): 1,
#          ('36ba5561e351eef68d3554697132a9a8',
#           '53c61580d8e5c4941a358ee0335c1d5c'): 2,
#          ('e53e557d5a159f5aa2c5e995dfdf244b',
#           '36f60d45225e60c7da4558b070ce4b60'): 28,
#          ('92503fc18ca14a8f32c182ce3f1b9f05',
#           '92503fc18ca14a8f32c182ce3f1b9f05'): 4,
#          ('880be32f4db1d9f6e2bec38fb6ac23ab',
#           '880be32f4db1d9f6e2bec38fb6ac23ab'): 5,
#          ('d1c427060a0f73f6b889a5c7c61f2ac4',
#           '7a8dfec813ae58cfaa3e1ef9f534adab'): 1,
#          ('84f456958365164420cfc80fbe4c7fab',
#           '84f456958365164420cfc80fbe4c7fab'): 6,
#          ...})

# %%
# Check out the most common combination:

for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('422879e10f46682990de24d770e7f83d', '422879e10f46682990de24d770e7f83d') 279
# ('ee3d532c8a438679776d222e997606b3', 'ee3d532c8a438679776d222e997606b3') 195
# ('9571759451b1d780ee7c15012ea109d4', '9571759451b1d780ee7c15012ea109d4') 190
# ('a62e25e09e05e6faf31d90c6ec1aa3d1', 'a62e25e09e05e6faf31d90c6ec1aa3d1') 141
# ('368c6c730842d78016ad823897a372db', '368c6c730842d78016ad823897a372db') 139
# ('b532349fe46b38fbc7bb3914c1bdae07', 'b532349fe46b38fbc7bb3914c1bdae07') 133
# ('d5991653e037ccb7af6ed7d94246b249', 'd5991653e037ccb7af6ed7d94246b249') 123
# ('53759a2ecddad2bb87a079a1f1519f73', '53759a2ecddad2bb87a079a1f1519f73') 119
# ('89b190a046022486c635022524a974a8', '89b190a046022486c635022524a974a8') 115
# ('aca2eb7d00ea1a7b8ebd4e68314663af', 'aca2eb7d00ea1a7b8ebd4e68314663af') 110

# %%
# Combination of product_category_name:

cross_selling2 = pd.merge(pd.merge(orders, order_items, how='left', on='order_id'), products, on = 'product_id')

# %%
# Create a combination of groups so that can be used as an alternative to pairing
df2 = cross_selling2
df2 = df2.dropna()
df2 = df2[df2['order_id'].duplicated(keep = False)]
df2['products'] = df2.groupby('order_id')['product_category_name'].transform(lambda x:','.join(x))
df2 = df2[['order_id', 'products']].drop_duplicates()
df2.head()
# Out:
#                             order_id             products
# 28  d543201a9b42a1402ff97e65b439a48b  Perfumery,Perfumery
# 30  78037c5f4d9f1f7bab0207f22c4e92f1  Perfumery,Perfumery
# 38  9883744c6400cfad8a620ddb82b9793c  Perfumery,Perfumery
# 49  70b552ddd260593a445a635431384e35  Perfumery,Perfumery
# 61  f4d33a3db484fba77b5f1f1990fb3445  Perfumery,Perfumery

# %%
# Count each row combination by the the pairing of the two:

count = Counter()
for row in df2['products']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

count
# Out:
# Counter({('Perfumery', 'Perfumery'): 347,
#          ('Pet_Shop', 'Pet_Shop'): 321,
#          ('Stationery', 'Stationery'): 260,
#          ('Auto', 'Auto'): 611,
#          ('Furniture_Decor', 'Furniture_Decor'): 2969,
#          ('Garden_Tools', 'Garden_Tools'): 1428,
#          ('Bed_Bath_Table', 'Bed_Bath_Table'): 2353,
#          ('Toys', 'Toys'): 290,
#          ('Health_Beauty', 'Health_Beauty'): 1327,
#          ('Cool_Stuff', 'Baby'): 11,
#          ('Baby', 'Baby'): 284,
#          ('Watches_Gifts', 'Watches_Gifts'): 577,
#          ('Watches_Gifts', 'Electronics'): 2,
#          ('Electronics', 'Computers_Accessories'): 5,
#          ('Garden_Tools', 'Computers_Accessories'): 7,
#          ('Garden_Tools', 'Housewares'): 12,
#          ('Furniture_Decor', 'Housewares'): 18,
#          ('Books_General_Interest', 'Books_General_Interest'): 53,
#          ('Small_Appliances', 'Small_Appliances'): 63,
#          ('Sports_Leisure', 'Sports_Leisure'): 1214,
#          ('Sports_Leisure', 'Furniture_Decor'): 1,
#          ('Telephony', 'Telephony'): 580,
#          ('Food', 'Food'): 89,
#          ('Computers_Accessories', 'Luggage_Accessories'): 2,
#          ('Computers_Accessories', 'Computers_Accessories'): 1944,
#          ('Computers_Accessories', 'Garden_Tools'): 17,
#          ('Computers_Accessories', 'Housewares'): 1,
#          ('Computers_Accessories', 'Air_Conditioning'): 1,
#          ('Computers_Accessories', 'Electronics'): 15,
#          ('Electronics', 'Electronics'): 290,
#          ('Construction_Tools_Construction',
#           'Construction_Tools_Construction'): 347,
#          ('Telephony', 'Garden_Tools'): 1,
#          ('Baby', 'Housewares'): 5,
#          ('Air_Conditioning', 'Air_Conditioning'): 63,
#          ('Housewares', 'Housewares'): 1951,
#          ('Auto', 'Telephony'): 2,
#          ('Watches_Gifts', 'Telephony'): 1,
#          ('Office_Furniture', 'Office_Furniture'): 820,
#          ('Watches_Gifts', 'Auto'): 1,
#          ('Furniture_Decor', 'Baby'): 16,
#          ('Baby', 'Cool_Stuff'): 12,
#          ('Cool_Stuff', 'Cool_Stuff'): 239,
#          ('Furniture_Decor', 'Kitchen_Dining_Laundry_Garden_Furniture'): 1,
#          ('Furniture_Decor', 'Furniture_Living_Room'): 7,
#          ('Furniture_Decor', 'Bed_Bath_Table'): 59,
#          ('Furniture_Decor', 'Health_Beauty'): 3,
#          ('Watches_Gifts', 'Cool_Stuff'): 1,
#          ('Bed_Bath_Table', 'Home_Confort'): 38,
#          ('Home_Confort', 'Home_Confort'): 48,
#          ('Fashion_Bags_Accessories', 'Fashion_Bags_Accessories'): 222,
#          ('Housewares', 'Cool_Stuff'): 1,
#          ('Bed_Bath_Table', 'Office_Furniture'): 5,
#          ('Musical_Instruments', 'Musical_Instruments'): 48,
#          ('Watches_Gifts', 'Audio'): 5,
#          ('Sports_Leisure', 'Health_Beauty'): 8,
#          ('Perfumery', 'Health_Beauty'): 10,
#          ('Garden_Tools', 'Home_Construction'): 7,
#          ('Garden_Tools', 'Furniture_Decor'): 55,
#          ('Garden_Tools', 'Sports_Leisure'): 6,
#          ('Construction_Tools_Lights', 'Construction_Tools_Lights'): 108,
#          ('Books_Technical', 'Costruction_Tools_Garden'): 1,
#          ('Market_Place', 'Market_Place'): 58,
#          ('Baby', 'Furniture_Decor'): 5,
#          ('Agro_Industry_And_Commerce', 'Agro_Industry_And_Commerce'): 52,
#          ('Cds_Dvds_Musicals', 'Cds_Dvds_Musicals'): 2,
#          ('Furniture_Decor', 'Construction_Tools_Lights'): 7,
#          ('Furniture_Decor', 'Art'): 3,
#          ('Industry_Commerce_And_Business',
#           'Industry_Commerce_And_Business'): 39,
#          ('Industry_Commerce_And_Business', 'Furniture_Decor'): 3,
#          ('Computers_Accessories', 'Auto'): 4,
#          ('Computers_Accessories', 'Telephony'): 4,
#          ('Health_Beauty', 'Watches_Gifts'): 2,
#          ('Watches_Gifts', 'Garden_Tools'): 3,
#          ('Kitchen_Dining_Laundry_Garden_Furniture',
#           'Kitchen_Dining_Laundry_Garden_Furniture'): 42,
#          ('Kitchen_Dining_Laundry_Garden_Furniture', 'Toys'): 1,
#          ('Sports_Leisure', 'Office_Furniture'): 12,
#          ('Toys', 'Consoles_Games'): 2,
#          ('Toys', 'Baby'): 8,
#          ('Health_Beauty', 'Pet_Shop'): 1,
#          ('Health_Beauty', 'Sports_Leisure'): 6,
#          ('Baby', 'Bed_Bath_Table'): 17,
#          ('Fashion_Shoes', 'Fashion_Shoes'): 29,
#          ('Bed_Bath_Table', 'Furniture_Decor'): 69,
#          ('Bed_Bath_Table', 'Food'): 1,
#          ('Home_Confort', 'Bed_Bath_Table'): 20,
#          ('Home_Construction', 'Home_Construction'): 184,
#          ('Home_Construction', 'Construction_Tools_Safety'): 6,
#          ('Construction_Tools_Safety', 'Construction_Tools_Safety'): 45,
#          ('Audio', 'Audio'): 15,
#          ('Garden_Tools', 'Baby'): 9,
#          ('Furniture_Decor', 'Home_Construction'): 7,
#          ('Perfumery', 'Toys'): 1,
#          ('Toys', 'Perfumery'): 2,
#          ('Baby', 'Toys'): 18,
#          ('Cool_Stuff', 'Consoles_Games'): 1,
#          ('Bed_Bath_Table', 'Auto'): 2,
#          ('Garden_Tools', 'Watches_Gifts'): 1,
#          ('Watches_Gifts', 'Furniture_Decor'): 7,
#          ('Consoles_Games', 'Consoles_Games'): 99,
#          ('Food', 'Pet_Shop'): 2,
#          ('Consoles_Games', 'Sports_Leisure'): 1,
#          ('Sports_Leisure', 'Housewares'): 8,
#          ('Health_Beauty', 'Baby'): 1,
#          ('Cool_Stuff', 'Bed_Bath_Table'): 9,
#          ('Fixed_Telephony', 'Fixed_Telephony'): 92,
#          ('Construction_Tools_Lights', 'Furniture_Decor'): 13,
#          ('Construction_Tools_Lights', 'Home_Construction'): 1,
#          ('Luggage_Accessories', 'Luggage_Accessories'): 67,
#          ('Bed_Bath_Table', 'Health_Beauty'): 8,
#          ('Sports_Leisure', 'Perfumery'): 1,
#          ('Computers_Accessories', 'Cool_Stuff'): 5,
#          ('Computers_Accessories', 'Home_Construction'): 3,
#          ('Cool_Stuff', 'Home_Construction'): 1,
#          ('Watches_Gifts', 'Housewares'): 1,
#          ('Home_Confort', 'Housewares'): 1,
#          ('Drinks', 'Drinks'): 159,
#          ('Toys', 'Watches_Gifts'): 1,
#          ('Housewares', 'Industry_Commerce_And_Business'): 4,
#          ('Furniture_Decor', 'Garden_Tools'): 4,
#          ('Art', 'Furniture_Decor'): 4,
#          ('Art', 'Art'): 2,
#          ('Furniture_Living_Room', 'Furniture_Living_Room'): 156,
#          ('Furniture_Living_Room', 'Furniture_Decor'): 4,
#          ('Furniture_Living_Room', 'Baby'): 1,
#          ('Construction_Tools_Safety', 'Computers_Accessories'): 1,
#          ('Health_Beauty', 'Housewares'): 1,
#          ('Toys', 'Bed_Bath_Table'): 2,
#          ('Telephony', 'Cool_Stuff'): 7,
#          ('Office_Furniture', 'Bed_Bath_Table'): 6,
#          ('Bed_Bath_Table', 'Cool_Stuff'): 2,
#          ('Bed_Bath_Table', 'Furniture_Living_Room'): 1,
#          ('Costruction_Tools_Garden', 'Costruction_Tools_Garden'): 53,
#          ('Housewares', 'Baby'): 3,
#          ('Stationery', 'Luggage_Accessories'): 5,
#          ('Tablets_Printing_Image', 'Cool_Stuff'): 2,
#          ('Tablets_Printing_Image', 'Tablets_Printing_Image'): 4,
#          ('Tablets_Printing_Image', 'Computers_Accessories'): 1,
#          ('Computers_Accessories', 'Office_Furniture'): 1,
#          ('Housewares', 'Furniture_Decor'): 19,
#          ('Health_Beauty', 'Bed_Bath_Table'): 7,
#          ('Health_Beauty', 'Cool_Stuff'): 3,
#          ('Market_Place', 'Health_Beauty'): 1,
#          ('Luggage_Accessories', 'Musical_Instruments'): 1,
#          ('Luggage_Accessories', 'Auto'): 1,
#          ('Baby', 'Fashion_Shoes'): 1,
#          ('Sports_Leisure', 'Food_Drink'): 1,
#          ('Watches_Gifts', 'Sports_Leisure'): 4,
#          ('Fashion_Bags_Accessories', 'Stationery'): 1,
#          ('Cool_Stuff', 'Construction_Tools_Safety'): 2,
#          ('Fashion_Bags_Accessories', 'Fashion_Sport'): 1,
#          ('Cool_Stuff', 'Computers_Accessories'): 2,
#          ('Sports_Leisure', 'Watches_Gifts'): 1,
#          ('Bed_Bath_Table', 'Housewares'): 25,
#          ('Stationery', 'Housewares'): 2,
#          ('Garden_Tools', 'Bed_Bath_Table'): 6,
#          ('Garden_Tools', 'Furniture_Living_Room'): 1,
#          ('Garden_Tools', 'Pet_Shop'): 1,
#          ('Market_Place', 'Housewares'): 1,
#          ('La_Cuisine', 'La_Cuisine'): 1,
#          ('Bed_Bath_Table', 'Pet_Shop'): 1,
#          ('Perfumery', 'Pet_Shop'): 1,
#          ('Pet_Shop', 'Furniture_Decor'): 1,
#          ('Pet_Shop', 'Sports_Leisure'): 1,
#          ('Furniture_Decor', 'Sports_Leisure'): 2,
#          ('Food_Drink', 'Food_Drink'): 77,
#          ('Market_Place', 'Books_General_Interest'): 2,
#          ('Computers', 'Computers'): 30,
#          ('Toys', 'Stationery'): 4,
#          ('Furniture_Decor', 'Furniture_Bedroom'): 1,
#          ('Garden_Tools', 'Electronics'): 1,
#          ('Garden_Tools', 'Construction_Tools_Lights'): 1,
#          ('Bed_Bath_Table', 'Construction_Tools_Lights'): 1,
#          ('Telephony', 'Toys'): 1,
#          ('Food', 'Health_Beauty'): 3,
#          ('Electronics', 'Food'): 1,
#          ('Auto', 'Health_Beauty'): 1,
#          ('Toys', 'Cool_Stuff'): 5,
#          ('Fashion_Bags_Accessories', 'Health_Beauty'): 1,
#          ('Stationery', 'Toys'): 2,
#          ('Telephony', 'Electronics'): 2,
#          ('Garden_Tools', 'La_Cuisine'): 1,
#          ('Housewares', 'Food_Drink'): 3,
#          ('Computers_Accessories', 'Sports_Leisure'): 3,
#          ('Furniture_Decor', 'Musical_Instruments'): 2,
#          ('Sports_Leisure', 'Drinks'): 3,
#          ('Auto', 'Sports_Leisure'): 2,
#          ('Furniture_Decor', 'Home_Confort'): 4,
#          ('Home_Confort', 'Furniture_Decor'): 5,
#          ('Cool_Stuff', 'Toys'): 3,
#          ('Christmas_Supplies', 'Christmas_Supplies'): 48,
#          ('Christmas_Supplies', 'Auto'): 2,
#          ('Stationery', 'Health_Beauty'): 2,
#          ('Health_Beauty', 'Telephony'): 1,
#          ('Books_Technical', 'Books_Technical'): 7,
#          ('Home_Comfort_2', 'Home_Comfort_2'): 7,
#          ('Home_Comfort_2', 'Musical_Instruments'): 1,
#          ('Home_Comfort_2', 'Auto'): 1,
#          ('Toys', 'Sports_Leisure'): 1,
#          ('Watches_Gifts', 'Stationery'): 2,
#          ('Bed_Bath_Table', 'Furniture_Bedroom'): 1,
#          ('Housewares', 'Computers_Accessories'): 3,
#          ('Market_Place', 'Furniture_Decor'): 3,
#          ('Market_Place', 'Bed_Bath_Table'): 11,
#          ('Watches_Gifts', 'Computers_Accessories'): 1,
#          ('Telephony', 'Auto'): 4,
#          ('Telephony', 'Watches_Gifts'): 1,
#          ('Consoles_Games', 'Auto'): 2,
#          ('Housewares', 'Garden_Tools'): 3,
#          ('Electronics', 'Bed_Bath_Table'): 3,
#          ('Construction_Tools_Construction', 'Toys'): 1,
#          ('Telephony', 'Costruction_Tools_Garden'): 1,
#          ('Furniture_Decor', 'Cool_Stuff'): 2,
#          ('Watches_Gifts', 'Baby'): 2,
#          ('Sports_Leisure', 'Toys'): 3,
#          ('Housewares', 'Stationery'): 3,
#          ('Watches_Gifts', 'Health_Beauty'): 1,
#          ('Home_Appliances_2', 'Home_Appliances_2'): 4,
#          ('Health_Beauty', 'Drinks'): 1,
#          ('Computers_Accessories', 'Stationery'): 2,
#          ('Cool_Stuff', 'Telephony'): 1,
#          ('Fashion_Sport', 'Fashion_Sport'): 6,
#          ('Luggage_Accessories', 'Garden_Tools'): 2,
#          ('Home_Construction', 'Furniture_Decor'): 12,
#          ('Auto', 'Housewares'): 1,
#          ('Housewares', 'Watches_Gifts'): 1,
#          ('Perfumery', 'Furniture_Decor'): 1,
#          ('Bed_Bath_Table', 'Baby'): 5,
#          ('Furniture_Decor', 'Pet_Shop'): 2,
#          ('Construction_Tools_Construction', 'Pet_Shop'): 3,
#          ('Health_Beauty', 'Perfumery'): 4,
#          ('Audio', 'Watches_Gifts'): 1,
#          ('Costruction_Tools_Garden', 'Pet_Shop'): 1,
#          ('Furniture_Decor', 'Office_Furniture'): 5,
#          ('Furniture_Decor', 'Computers'): 2,
#          ('Fashion_Bags_Accessories', 'Fashion_Childrens_Clothes'): 1,
#          ('Housewares', 'Kitchen_Dining_Laundry_Garden_Furniture'): 1,
#          ('Watches_Gifts', 'Home_Confort'): 1,
#          ('Health_Beauty', 'Stationery'): 7,
#          ('Health_Beauty', 'Market_Place'): 1,
#          ('Housewares', 'Auto'): 2,
#          ('Health_Beauty', 'Books_Technical'): 1,
#          ('Furniture_Decor', 'Stationery'): 2,
#          ('Baby', 'Auto'): 2,
#          ('Housewares', 'Bed_Bath_Table'): 12,
#          ('Baby', 'Luggage_Accessories'): 1,
#          ('Perfumery', 'Sports_Leisure'): 2,
#          ('Telephony', 'Small_Appliances'): 2,
#          ('Office_Furniture', 'Furniture_Decor'): 1,
#          ('Housewares', 'Perfumery'): 1,
#          ('Signaling_And_Security', 'Signaling_And_Security'): 108,
#          ('Health_Beauty', 'Food'): 1,
#          ('Cine_Photo', 'Cine_Photo'): 10,
#          ('Auto', 'Construction_Tools_Construction'): 2,
#          ('Housewares', 'Drinks'): 1,
#          ('Electronics', 'Perfumery'): 2,
#          ('Housewares', 'Market_Place'): 1,
#          ('Furniture_Decor', 'Auto'): 4,
#          ('Small_Appliances', 'Housewares'): 2,
#          ('Perfumery', 'Watches_Gifts'): 1,
#          ('Food_Drink', 'Sports_Leisure'): 1,
#          ('Home_Appliances', 'Home_Appliances'): 7,
#          ('Cool_Stuff', 'Furniture_Decor'): 2,
#          ('Furniture_Decor', 'Market_Place'): 1,
#          ('Fashion_Underwear_Beach', 'Fashion_Underwear_Beach'): 16,
#          ('Office_Furniture', 'Industry_Commerce_And_Business'): 1,
#          ('Consoles_Games', 'Pet_Shop'): 1,
#          ('Drinks', 'Sports_Leisure'): 1,
#          ('Diapers_And_Hygiene', 'Diapers_And_Hygiene'): 27,
#          ('Auto', 'Cool_Stuff'): 3,
#          ('Auto', 'Bed_Bath_Table'): 1,
#          ('Costruction_Tools_Tools', 'Costruction_Tools_Tools'): 6,
#          ('Watches_Gifts', 'Construction_Tools_Construction'): 1,
#          ('Garden_Tools', 'Construction_Tools_Construction'): 2,
#          ('Electronics', 'Housewares'): 5,
#          ('Furniture_Bedroom', 'Furniture_Bedroom'): 14,
#          ('Furniture_Decor', 'Electronics'): 2,
#          ('Electronics', 'Furniture_Decor'): 1,
#          ('Electronics', 'Auto'): 1,
#          ('Fashion_Bags_Accessories', 'Baby'): 3,
#          ('Construction_Tools_Safety', 'Bed_Bath_Table'): 1,
#          ('Housewares', 'Sports_Leisure'): 5,
#          ('Sports_Leisure', 'Auto'): 2,
#          ('Computers_Accessories', 'Consoles_Games'): 1,
#          ('Bed_Bath_Table', 'Garden_Tools'): 2,
#          ('Stationery', 'Sports_Leisure'): 2,
#          ('Fashio_Female_Clothing', 'Fashio_Female_Clothing'): 18,
#          ('Books_Imported', 'Books_Imported'): 7,
#          ('Flowers', 'Costruction_Tools_Garden'): 1,
#          ('Food', 'Sports_Leisure'): 1,
#          ('Sports_Leisure', 'Food'): 1,
#          ('Baby', 'Construction_Tools_Lights'): 2,
#          ('Bed_Bath_Table', 'Home_Appliances_2'): 1,
#          ('Costruction_Tools_Garden', 'Bed_Bath_Table'): 2,
#          ('Sports_Leisure', 'Cool_Stuff'): 1,
#          ('Musical_Instruments', 'Watches_Gifts'): 1,
#          ('Cool_Stuff', 'Watches_Gifts'): 1,
#          ('Party_Supplies', 'Party_Supplies'): 4,
#          ('Stationery', 'Art'): 1,
#          ('Telephony', 'Fixed_Telephony'): 1,
#          ('Baby', 'Sports_Leisure'): 1,
#          ('Garden_Tools', 'Costruction_Tools_Garden'): 1,
#          ('Computers_Accessories', 'Dvds_Blu_Ray'): 1,
#          ('Office_Furniture', 'Furniture_Living_Room'): 4,
#          ('Housewares', 'Consoles_Games'): 1,
#          ('Fashion_Male_Clothing', 'Fashion_Male_Clothing'): 23,
#          ('Food', 'Fixed_Telephony'): 1,
#          ('Telephony', 'Computers_Accessories'): 2,
#          ('Construction_Tools_Lights', 'Costruction_Tools_Garden'): 1,
#          ('Housewares', 'Construction_Tools_Construction'): 1,
#          ('Housewares', 'Home_Construction'): 3,
#          ('Health_Beauty', 'Luggage_Accessories'): 2,
#          ('Luggage_Accessories', 'Telephony'): 1,
#          ('Electronics', 'Small_Appliances'): 1,
#          ('Home_Construction', 'Garden_Tools'): 1,
#          ('Arts_And_Craftmanship', 'Garden_Tools'): 1,
#          ('Furniture_Decor', 'Books_Technical'): 1,
#          ('Construction_Tools_Safety', 'Home_Construction'): 1,
#          ('Stationery', 'Garden_Tools'): 2,
#          ('Music', 'Perfumery'): 1,
#          ('Construction_Tools_Safety', 'Baby'): 1,
#          ('Auto', 'Garden_Tools'): 3,
#          ('Health_Beauty', 'Construction_Tools_Construction'): 2,
#          ('Home_Construction', 'Housewares'): 1,
#          ('Construction_Tools_Construction', 'Auto'): 2,
#          ('Sports_Leisure', 'Construction_Tools_Lights'): 2,
#          ('Construction_Tools_Lights', 'Sports_Leisure'): 1,
#          ('Small_Appliances', 'Health_Beauty'): 1,
#          ('Books_General_Interest', 'Baby'): 1,
#          ('Electronics', 'Sports_Leisure'): 1,
#          ('Flowers', 'Flowers'): 4,
#          ('Dvds_Blu_Ray', 'Dvds_Blu_Ray'): 5,
#          ('Toys', 'Arts_And_Craftmanship'): 1,
#          ('Cool_Stuff', 'Health_Beauty'): 1,
#          ('Construction_Tools_Construction', 'Garden_Tools'): 4,
#          ('Furniture_Decor', 'Perfumery'): 1,
#          ('Fashion_Childrens_Clothes', 'Fashion_Bags_Accessories'): 1,
#          ('Computers_Accessories', 'Construction_Tools_Construction'): 1,
#          ('Furniture_Bedroom', 'Baby'): 1,
#          ('Bed_Bath_Table', 'Sports_Leisure'): 2,
#          ('Cool_Stuff', 'Books_General_Interest'): 1,
#          ('Dvds_Blu_Ray', 'Housewares'): 2,
#          ('Perfumery', 'Market_Place'): 1,
#          ('Perfumery', 'Bed_Bath_Table'): 1,
#          ('Luggage_Accessories', 'Electronics'): 1,
#          ('Drinks', 'Health_Beauty'): 16,
#          ('Auto', 'Drinks'): 2,
#          ('Signaling_And_Security', 'Baby'): 1,
#          ('Baby', 'La_Cuisine'): 1,
#          ('Furniture_Living_Room', 'Bed_Bath_Table'): 1,
#          ('Books_General_Interest', 'Housewares'): 1,
#          ('Books_Technical', 'Music'): 1,
#          ('Construction_Tools_Construction',
#           'Kitchen_Dining_Laundry_Garden_Furniture'): 1,
#          ('Fashion_Shoes', 'Baby'): 1,
#          ('Luggage_Accessories', 'Stationery'): 1,
#          ('Computers_Accessories', 'Furniture_Decor'): 2,
#          ('Party_Supplies', 'Bed_Bath_Table'): 1,
#          ('Small_Appliances', 'Furniture_Decor'): 3,
#          ('Telephony', 'Cine_Photo'): 2,
#          ('Cine_Photo', 'Cool_Stuff'): 2,
#          ('Electronics', 'Home_Construction'): 1,
#          ('Kitchen_Dining_Laundry_Garden_Furniture', 'Housewares'): 1,
#          ('Market_Place', 'Musical_Instruments'): 1,
#          ('Stationery', 'Fashion_Bags_Accessories'): 1,
#          ('Small_Appliances', 'Sports_Leisure'): 2,
#          ('Fashio_Female_Clothing', 'Fashion_Sport'): 1,
#          ('Telephony', 'Health_Beauty'): 1,
#          ('Costruction_Tools_Garden', 'Home_Construction'): 1,
#          ('Construction_Tools_Construction', 'Bed_Bath_Table'): 1,
#          ('Auto', 'Computers_Accessories'): 1,
#          ('Computers_Accessories', 'Bed_Bath_Table'): 1,
#          ('Small_Appliances_Home_Oven_And_Coffee',
#           'Small_Appliances_Home_Oven_And_Coffee'): 1,
#          ('Cine_Photo', 'Sports_Leisure'): 1,
#          ('Sports_Leisure', 'Air_Conditioning'): 1,
#          ('Furniture_Living_Room', 'Toys'): 2,
#          ('Toys', 'Health_Beauty'): 2,
#          ('Furniture_Decor', 'Construction_Tools_Construction'): 1,
#          ('Furniture_Living_Room', 'Office_Furniture'): 1,
#          ('Office_Furniture', 'Sports_Leisure'): 1,
#          ('Auto', 'Fashion_Bags_Accessories'): 1,
#          ('Auto', 'Musical_Instruments'): 1,
#          ('Fashion_Bags_Accessories', 'Musical_Instruments'): 1,
#          ('Musical_Instruments', 'Toys'): 4,
#          ('Drinks', 'Housewares'): 1,
#          ('Kitchen_Dining_Laundry_Garden_Furniture', 'Bed_Bath_Table'): 3,
#          ('Computers_Accessories', 'Health_Beauty'): 1,
#          ('Flowers', 'Furniture_Decor'): 6,
#          ('Arts_And_Craftmanship', 'Arts_And_Craftmanship'): 1})

# %%
# Check out the most common combination: 

for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('Furniture_Decor', 'Furniture_Decor') 2969
# ('Bed_Bath_Table', 'Bed_Bath_Table') 2353
# ('Housewares', 'Housewares') 1951
# ('Computers_Accessories', 'Computers_Accessories') 1944
# ('Garden_Tools', 'Garden_Tools') 1428
# ('Health_Beauty', 'Health_Beauty') 1327
# ('Sports_Leisure', 'Sports_Leisure') 1214
# ('Office_Furniture', 'Office_Furniture') 820
# ('Auto', 'Auto') 611
# ('Telephony', 'Telephony') 580

# %% [markdown]
# ### 4. Payment Behaviour
# ### (a) How customers are paying?

# %%
order_payments.groupby('payment_type').agg(count = ('payment_type', 'count'))
# Out:
#               count
# payment_type
# UPI           19784
# credit_card   76795
# debit_card     1529
# not_defined       3
# voucher        5775

# %% [markdown]
# ### (b) Which payment channels are used by most customers?

# %%
order_payments.groupby('payment_type').agg(count = ('payment_type', 'count')).plot.bar(figsize = (10, 6))
# Out:
# <AxesSubplot:xlabel='payment_type'>

# %% [markdown]
# #### As per the above observation, "Credit Card" is used by most customers.

# %% [markdown]
# ### 5. Customer satisfaction towards category & product
# ### (a) Which categories (top 10) are maximum rated & minimum rated?

# %%
prod_cat = pd.merge(pd.merge(order_items, order_review_ratings, on = 'order_id'), products, on = 'product_id')

# %%
# Top 10 Maximum Rated Categories

prod_cat.groupby('product_category_name')['review_score'].mean().sort_values(ascending = False).head(10).reset_index()
# Out:
#                    product_category_name  review_score
# 0                      Cds_Dvds_Musicals      4.642857
# 1              Fashion_Childrens_Clothes      4.500000
# 2                 Books_General_Interest      4.439421
# 3                         Books_Imported      4.400000
# 4                Costruction_Tools_Tools      4.359223
# 5                        Books_Technical      4.338290
# 6                    Luggage_Accessories      4.309524
# 7                             Food_Drink      4.303571
# 8  Small_Appliances_Home_Oven_And_Coffee      4.302632
# 9                          Fashion_Sport      4.258065

# %%
# Top 10 Minimum Rated Categories

prod_cat.groupby('product_category_name')['review_score'].mean().sort_values(ascending = True).head(10).reset_index()
# Out:
#     product_category_name  review_score
# 0   Security_And_Services      2.500000
# 1     Diapers_And_Hygiene      3.256410
# 2          Home_Comfort_2      3.366667
# 3        Office_Furniture      3.484421
# 4   Fashion_Male_Clothing      3.621212
# 5         Fixed_Telephony      3.671698
# 6          Party_Supplies      3.767442
# 7  Fashio_Female_Clothing      3.780000
# 8              La_Cuisine      3.785714
# 9                   Audio      3.808219

# %% [markdown]
# ### (b) Which products (top10) are maximum rated & minimum rated?

# %%
products_ = pd.merge(pd.merge(order_items, order_review_ratings, on = 'order_id'), products, on = 'product_id')

# %%
# Top 10 Maximum Rated Products

products_.groupby('product_id')['review_score'].mean().sort_values(ascending = False).head(10).reset_index()
# Out:
#                          product_id  review_score
# 0  00066f42aeeb9f3007548bb9d3f33c38           5.0
# 1  86743ff92eee3d16b7df59cddd583b8c           5.0
# 2  868ceb027ab706a4dee42e2220006b85           5.0
# 3  868969d3a93aeeab7bfcd4fc3d3d65de           5.0
# 4  868766ed2172644fdd977d6bd395a107           5.0
# 5  8684bd8f93b4f4038d07188a23811e93           5.0
# 6  867c96d2bb67aba6500a4c509cf76072           5.0
# 7  867b820367ec206b38a357f2c12454b7           5.0
# 8  867901d7e8488fb97f1fb538c09d476e           5.0
# 9  865bfa00c1dad8f4146d3c2765f051ca           5.0

# %%
# Top 10 Minimum Rated Products

products_.groupby('product_id')['review_score'].mean().sort_values(ascending = True).head(10).reset_index()
# Out:
#                          product_id  review_score
# 0  592cc6634d2c783d297effc0b828bc37           1.0
# 1  28c95d7653177449fd4b6fc7adb63ce9           1.0
# 2  28d6d6a10ceb0636ae572e7efafef612           1.0
# 3  28d7da9ebe96bfda54aed060b68b23a1           1.0
# 4  8c4e5e50a08a443b7fbad34ad7587625           1.0
# 5  8c4dc358af6e14174f2114be62c18f37           1.0
# 6  8c4456c061013adccb1ba4cbce2d0365           1.0
# 7  8c35dc99b37ba51780800ba049ed3616           1.0
# 8  28fe66c8a81afe9be7829f40a5fae9ee           1.0
# 9  ee37349d258101b9d573a256d1401ff7           1.0

# %% [markdown]
# ### (c) Average rating by location, seller, product, category, month etc.

# %%
# Average rating by location

loc_ratings = pd.merge(pd.merge(orders, order_review_ratings, on = 'order_id'), customers, on = 'customer_id')
loc_ratings.groupby('customer_state')['review_score'].mean().sort_values(ascending = False).reset_index()
# Out:
#        customer_state  review_score
# 0                 Goa      4.800000
# 1              Punjab      4.197947
# 2           Rajasthan      4.189889
# 3          Tamil Nadu      4.161820
# 4       Uttar Pradesh      4.155405
# 5             Haryana      4.149955
# 6              Orissa      4.142173
# 7              Kerala      4.141001
# 8         Maharashtra      4.129786
# 9   Arunachal Pradesh      4.119153
# 10       Chhattisgarh      4.089828
# 11            Gujarat      4.085364
# 12     Madhya Pradesh      4.085136
# 13    Jammu & Kashmir      4.084142
# 14          Karnataka      4.074910
# 15              Delhi      4.061286
# 16     Andhra Pradesh      4.051443
# 17        West Bengal      4.046070
# 18   Himachal Pradesh      4.022727
# 19        Uttaranchal      3.917526

# %%
# Average rating by seller

seller_ratings = pd.merge(order_items, order_review_ratings, on = 'order_id')
seller_ratings.groupby('seller_id')['review_score'].mean().sort_values(ascending = False).reset_index()
# Out:
#                              seller_id  review_score
# 0     c18309219e789960add0b2255ca4b091           5.0
# 1     c7246702dc991a06d788120dc7544391           5.0
# 2     eaaa46e98c9e61f6764dd1d7a2ab8b3e           5.0
# 3     466222e777149751370e7e98fb623b0c           5.0
# 4     ea846a0e7ad98a741783e886d89dfa44           5.0
# ...                                ...           ...
# 3090  dc120d932ddf9d4dfb6fd68beefda622           1.0
# 3091  749e7cdabbaf72f16677859e27874ba5           1.0
# 3092  dadc51ef321949ec9a3ab25cd902e23d           1.0
# 3093  da2782c804606d2a5d8e1760dbb3e7ec           1.0
# 3094  61b893c57e33626afb104d4112b1be76           1.0
#
# [3095 rows x 2 columns]

# %%
# Average rating by product

product_ratings = pd.merge(order_items, order_review_ratings, on = 'order_id')
product_ratings.groupby('product_id')['review_score'].mean().reset_index()
# Out:
#                              product_id  review_score
# 0      00066f42aeeb9f3007548bb9d3f33c38           5.0
# 1      00088930e925c41fd95ebfe695fd2655           4.0
# 2      0009406fd7479715e4bef61dd91f2462           1.0
# 3      000b8f95fcb9e0096488278317764d19           5.0
# 4      000d9be29b5207b54e86aa1b1ac54872           5.0
# ...                                 ...           ...
# 32946  fff6177642830a9a94a0f2cba5e476d1           4.5
# 32947  fff81cc3158d2725c0655ab9ba0f712c           4.0
# 32948  fff9553ac224cec9d15d49f5a263411f           5.0
# 32949  fffdb2d0ec8d6a61f0a0a0db3f25b441           5.0
# 32950  fffe9eeff12fcbd74a2f2b007dde0c58           4.0
#
# [32951 rows x 2 columns]

# %%
# Average rating by category

category_ratings = pd.merge(pd.merge(order_items, order_review_ratings, on = 'order_id'), products, on = 'product_id')
category_ratings.groupby('product_category_name')['review_score'].mean().reset_index()
# Out:
#          product_category_name  review_score
# 0   Agro_Industry_And_Commerce      4.000000
# 1             Air_Conditioning      3.919192
# 2                          Art      3.918660
# 3        Arts_And_Craftmanship      4.125000
# 4                        Audio      3.808219
# ..                         ...           ...
# 66                  Stationery      4.181386
# 67      Tablets_Printing_Image      4.048193
# 68                   Telephony      3.935604
# 69                        Toys      4.138667
# 70               Watches_Gifts      4.002000
#
# [71 rows x 2 columns]

# %%
# Average rating by month

month_ratings = order_review_ratings.copy()
month_ratings['year_month'] = month_ratings['review_creation_date'].dt.strftime('%Y-%m')
month_ratings.groupby('year_month')['review_score'].mean().reset_index()
# Out:
#    year_month  review_score
# 0     2016-10      4.033149
# 1     2016-11      3.166667
# 2     2016-12      2.270833
# 3     2017-01      4.338912
# 4     2017-02      4.269663
# 5     2017-03      4.012774
# 6     2017-04      4.025641
# 7     2017-05      4.086456
# 8     2017-06      4.109290
# 9     2017-07      4.167610
# 10    2017-08      4.213104
# 11    2017-09      4.164939
# 12    2017-10      4.170112
# 13    2017-11      4.098466
# 14    2017-12      3.913087
# 15    2018-01      4.045833
# 16    2018-02      3.990921
# 17    2018-03      3.711778
# 18    2018-04      3.902993
# 19    2018-05      4.179071
# 20    2018-06      4.189502
# 21    2018-07      4.273497
# 22    2018-08      4.197278
